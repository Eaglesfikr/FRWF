# %% [markdown]
# # Dual-Domain (Time + Freq) Fine-tuning
#
# Based on the dual-domain SupCon pretrained model (time + frequency).
# We finetune a classifier that uses both time and frequency features.
#
# N defines the number of labeled samples per class for fine-tuning.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import warnings
warnings.filterwarnings('ignore')
import numpy as np

from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import RandomSampler, SequentialSampler
import torch
from torch import nn
import torch.nn.functional as F
from torch import optim
from torch.autograd import Variable
import tqdm
import pickle
import argparse
from torch.cuda.amp import GradScaler, autocast

import random
import sys
import os
import collections
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## GPU Allocation

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu", 0)
kwargs = {'num_workers': 0, 'pin_memory': True} if use_cuda else {}
print(f'Device: {device}')
# Out:
# Device: cuda:0

# %% [markdown]
# ## Parameters

# %%
batch_size = 16

# %% [markdown]
# ## Loading the Fine-tuning Datasets
#
# Load both time domain and frequency domain data. Must be aligned.

# %%
DATASET = 'AWF'

if DATASET == 'AWF':
    # --- 时域数据 ---
    data_time = np.load('./datasets/awf2.npz')
    print('Time files:', data_time.files)
    x_time_total = data_time['data']
    y_total = data_time['labels']

    # --- 频域数据 ---
    data_freq = np.load('./datasets/awf2_freq.npz')
    print('Freq files:', data_freq.files)
    x_freq_total = data_freq['x']

print(f"Time shape: {x_time_total.shape}")
print(f"Freq shape: {x_freq_total.shape}")
print(f"Labels: {y_total.shape}")
assert len(x_time_total) == len(x_freq_total) == len(y_total), "Mismatched sample counts!"

num_classes = len(np.unique(y_total))
print(f"Number of classes: {num_classes}")
# Out:
# Time files: ['data', 'labels']
# Freq files: ['x', 'y']
# Time shape: (257500, 5000)
# Freq shape: (257500, 2500)
# Labels: (257500,)
# Number of classes: 103

# %%
# 训练/测试拆分（保持时域和频域的对齐）
x_time_train, x_time_test, x_freq_train, x_freq_test, y_train, y_test = train_test_split(
    x_time_total, x_freq_total, y_total, test_size=0.2, random_state=42, stratify=y_total)

print(f"Train: time {x_time_train.shape}, freq {x_freq_train.shape}, y {y_train.shape}")
print(f"Test:  time {x_time_test.shape}, freq {x_freq_test.shape}, y {y_test.shape}")
# Out:
# Train: time (206000, 5000), freq (206000, 2500), y (206000,)
# Test:  time (51500, 5000), freq (51500, 2500), y (51500,)

# %%
# 每个类别随机采样 N 个样本用于微调
def sample_traces(x_time, x_freq, y, N):
    train_index = []
    for c in range(num_classes):
        idx = np.where(y == c)[0]
        idx = np.random.choice(idx, min(N, len(idx)), False)
        train_index.extend(idx)
    train_index = np.array(train_index)
    np.random.shuffle(train_index)

    return x_time[train_index], x_freq[train_index], y[train_index]

# %% [markdown]
# ## Backbone Model
#
# Same DFNet as used in pretrain.

# %%
class DFNet(nn.Module):
    def __init__(self, out_dim, input_feature_dim):
        super(DFNet, self).__init__()
        kernel_size = 8
        conv_stride = 1
        pool_stride = 4
        pool_size = 8

        self.conv1 = nn.Conv1d(1, 32, kernel_size, stride=conv_stride)
        self.conv1_1 = nn.Conv1d(32, 32, kernel_size, stride=conv_stride)
        self.conv2 = nn.Conv1d(32, 64, kernel_size, stride=conv_stride)
        self.conv2_2 = nn.Conv1d(64, 64, kernel_size, stride=conv_stride)
        self.conv3 = nn.Conv1d(64, 128, kernel_size, stride=conv_stride)
        self.conv3_3 = nn.Conv1d(128, 128, kernel_size, stride=conv_stride)
        self.conv4 = nn.Conv1d(128, 256, kernel_size, stride=conv_stride)
        self.conv4_4 = nn.Conv1d(256, 256, kernel_size, stride=conv_stride)

        self.batch_norm1 = nn.BatchNorm1d(32)
        self.batch_norm2 = nn.BatchNorm1d(64)
        self.batch_norm3 = nn.BatchNorm1d(128)
        self.batch_norm4 = nn.BatchNorm1d(256)

        self.max_pool_1 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)
        self.max_pool_2 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)
        self.max_pool_3 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)
        self.max_pool_4 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)

        self.dropout1 = nn.Dropout(p=0.1)
        self.dropout2 = nn.Dropout(p=0.1)
        self.dropout3 = nn.Dropout(p=0.1)
        self.dropout4 = nn.Dropout(p=0.1)

        # 动态计算展平后的维度
        with torch.no_grad():
            dummy_input = torch.zeros(1, 1, input_feature_dim)
            out = self._forward_features(dummy_input)
            flattened_dim = out.view(1, -1).size(1)

        self.fc = nn.Linear(flattened_dim, out_dim)
        self.weight_init()

    def _forward_features(self, x):
        x = F.pad(x, (3,4))
        x = F.elu((self.conv1(x)))
        x = F.pad(x, (3,4))
        x = F.elu(self.batch_norm1(self.conv1_1(x)))
        x = F.pad(x, (3, 4))
        x = self.max_pool_1(x)
        x = self.dropout1(x)

        x = F.pad(x, (3,4))
        x = F.relu((self.conv2(x)))
        x = F.pad(x, (3,4))
        x = F.relu(self.batch_norm2(self.conv2_2(x)))
        x = F.pad(x, (3,4))
        x = self.max_pool_2(x)
        x = self.dropout2(x)

        x = F.pad(x, (3,4))
        x = F.relu((self.conv3(x)))
        x = F.pad(x, (3,4))
        x = F.relu(self.batch_norm3(self.conv3_3(x)))
        x = F.pad(x, (3,4))
        x = self.max_pool_3(x)
        x = self.dropout3(x)

        x = F.pad(x, (3,4))
        x = F.relu((self.conv4(x)))
        x = F.pad(x, (3,4))
        x = F.relu(self.batch_norm4(self.conv4_4(x)))
        x = F.pad(x, (3,4))
        x = self.max_pool_4(x)
        x = self.dropout4(x)
        return x

    def weight_init(self):
        for n, m in self.named_modules():
            if isinstance(m, nn.Linear) or isinstance(m, nn.Conv1d):
                torch.nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    m.bias.data.zero_()

    def forward(self, inp):
        x = self._forward_features(inp)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Dual-Domain Classifier (for finetuning)
#
# Uses both time_encoder and freq_encoder from the pretrained SupCon model.
# Concatenates their 512-dim outputs → 1024-dim → classifier head.

# %%
class DualDomainClassifier(nn.Module):
    def __init__(self, time_encoder, freq_encoder, num_classes):
        super().__init__()
        self.time_encoder = time_encoder
        self.freq_encoder = freq_encoder
        self.classifier = nn.Linear(1024, num_classes)

    def forward(self, x_time, x_freq):
        h_time = self.time_encoder(x_time)
        h_freq = self.freq_encoder(x_freq)
        out = torch.cat([h_time, h_freq], dim=1)
        return self.classifier(out)

# %% [markdown]
# ## Data Loader
#
# Returns aligned (time, freq, label) tuples.

# %%
class DualData(Dataset):
    def __init__(self, x_time, x_freq, y):
        self.x_time = x_time
        self.x_freq = x_freq
        self.y = y

    def __getitem__(self, index):
        return self.x_time[index], self.x_freq[index], self.y[index]

    def __len__(self):
        return len(self.y)

# %% [markdown]
# ## Loading the Pre-trained Dual-Domain Model
#
# We load the SupCon pretrained `time_encoder` and `freq_encoder` weights,
# skip the projectors, and add a new classifier head.
#
# **注意**: encoder 的 fc 维度 (512) 和 finetune 一致，所以包含 fc 层一起加载。
# 只跳过 `time_projector.*` / `freq_projector.*` 的投影头权重。

# %%
def load_checkpoint():
    """
    Load dual-domain SupCon pretrained model.
    Extract time_encoder and freq_encoder weights, skip projectors.
    """
    time_input_dim = x_time_train.shape[1]  # 5000
    freq_input_dim = x_freq_train.shape[1]   # 2500

    # 创建两个 encoder（和 pretrain 结构完全一致）
    time_encoder = DFNet(out_dim=512, input_feature_dim=time_input_dim)
    freq_encoder = DFNet(out_dim=512, input_feature_dim=freq_input_dim)

    # ===== 加载 dual-domain checkpoint =====
    checkpoint = torch.load('./checkpoints/supcon/WFTFC_dualsupcon_epoch_100.pth.tar')

    # 提取 time_encoder 权重
    time_state = {}
    for k, v in checkpoint.items():
        if k.startswith('time_encoder.'):
            new_k = k[len('time_encoder.'):]
            time_state[new_k] = v

    # 提取 freq_encoder 权重
    freq_state = {}
    for k, v in checkpoint.items():
        if k.startswith('freq_encoder.'):
            new_k = k[len('freq_encoder.'):]
            freq_state[new_k] = v

    # 加载 encoder 权重（fc 维度一致，全部加载）
    log_t = time_encoder.load_state_dict(time_state, strict=False)
    log_f = freq_encoder.load_state_dict(freq_state, strict=False)
    print(f"Time encoder missing: {log_t.missing_keys}")
    print(f"Freq encoder missing: {log_f.missing_keys}")

    # 组装分类器
    model = DualDomainClassifier(time_encoder, freq_encoder, num_classes).to(device)
    return model

# %% [markdown]
# ## Init Test Data Loaders

# %%
test_dataset = DualData(x_time_test, x_freq_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, drop_last=True)

# %% [markdown]
# ## Train and Test Functions
#
# Both take `(x_time, x_freq, target)` instead of just `(data, target)`.

# %%
def train(model, device, train_loader, optimizer):
    model.train()
    for batch_idx, (x_time, x_freq, target) in enumerate(train_loader):
        x_time = x_time.view(x_time.size(0), 1, x_time.size(1)).float().to(device)
        x_freq = x_freq.view(x_freq.size(0), 1, x_freq.size(1)).float().to(device)
        target = target.to(device).long()

        optimizer.zero_grad()
        output = model(x_time, x_freq)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print(f"Loss: {loss.item():.6f}")

def test(model, device, loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for x_time, x_freq, target in loader:
            x_time = x_time.view(x_time.size(0), 1, x_time.size(1)).float().to(device)
            x_freq = x_freq.view(x_freq.size(0), 1, x_freq.size(1)).float().to(device)
            target = target.to(device).long()

            output = model(x_time, x_freq)
            output = torch.softmax(output, dim=1)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).float().sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ## Running for 5 Times

# %%
# N defines the number of labeled samples per class for fine-tuning
N = 5

# %%
accuracies = []
for _ in range(5):
    x_time_ft, x_freq_ft, y_ft = sample_traces(x_time_train, x_freq_train, y_train, N)
    print(f"Input size: time {x_time_ft.shape}, freq {x_freq_ft.shape}, y {y_ft.shape}")

    train_dataset = DualData(x_time_ft, x_freq_ft, y_ft)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

    model = load_checkpoint()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    best_acc = 0
    for epoch in range(101):
        print(f"Epoch: {epoch}")
        train(model, device, train_loader, optimizer)

        acc = test(model, device, test_loader)
        best_acc = max(best_acc, acc)

        if epoch % 10 == 0:
            print(f"Accuracy on test dataset: {acc*100:.2f}")

    accuracies.append(best_acc)
    print('------------------------------------------------')
# Out:
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 6.918203
# Accuracy on test dataset: 9.23
# Epoch: 1
# Loss: 4.572049
# Epoch: 2
# Loss: 3.479195
# Epoch: 3
# Loss: 2.308496
# Epoch: 4
# Loss: 1.316331
# Epoch: 5
# Loss: 0.786191
# Epoch: 6
# Loss: 0.656121
# Epoch: 7
# Loss: 0.139788
# Epoch: 8
# Loss: 0.180641
# Epoch: 9
# Loss: 0.023332
# Epoch: 10
# Loss: 0.059323
# Accuracy on test dataset: 84.60
# Epoch: 11
# Loss: 0.035270
# Epoch: 12
# Loss: 0.010147
# Epoch: 13
# Loss: 0.019137
# Epoch: 14
# Loss: 0.014106
# Epoch: 15
# Loss: 0.046678
# Epoch: 16
# Loss: 0.089700
# Epoch: 17
# Loss: 0.002461
# Epoch: 18
# Loss: 0.005844
# Epoch: 19
# Loss: 0.002692
# Epoch: 20
# Loss: 0.001238
# Accuracy on test dataset: 87.77
# Epoch: 21
# Loss: 0.004879
# Epoch: 22
# Loss: 0.003458
# Epoch: 23
# Loss: 0.005772
# Epoch: 24
# Loss: 0.003675
# Epoch: 25
# Loss: 0.002923
# Epoch: 26
# Loss: 0.007306
# Epoch: 27
# Loss: 0.014053
# Epoch: 28
# Loss: 0.003339
# Epoch: 29
# Loss: 0.006164
# Epoch: 30
# Loss: 0.001319
# Accuracy on test dataset: 88.91
# Epoch: 31
# Loss: 0.000392
# Epoch: 32
# Loss: 0.002227
# Epoch: 33
# Loss: 0.003766
# Epoch: 34
# Loss: 0.000355
# Epoch: 35
# Loss: 0.001887
# Epoch: 36
# Loss: 0.001219
# Epoch: 37
# Loss: 0.001002
# Epoch: 38
# Loss: 0.000811
# Epoch: 39
# Loss: 0.015237
# Epoch: 40
# Loss: 0.000820
# Accuracy on test dataset: 89.33
# Epoch: 41
# Loss: 0.000245
# Epoch: 42
# Loss: 0.000518
# Epoch: 43
# Loss: 0.000680
# Epoch: 44
# Loss: 0.000948
# Epoch: 45
# Loss: 0.005378
# Epoch: 46
# Loss: 0.000899
# Epoch: 47
# Loss: 0.000581
# Epoch: 48
# Loss: 0.000742
# Epoch: 49
# Loss: 0.000264
# Epoch: 50
# Loss: 0.000547
# Accuracy on test dataset: 89.86
# Epoch: 51
# Loss: 0.000274
# Epoch: 52
# Loss: 0.001729
# Epoch: 53
# Loss: 0.001199
# Epoch: 54
# Loss: 0.000485
# Epoch: 55
# Loss: 0.001275
# Epoch: 56
# Loss: 0.000814
# Epoch: 57
# Loss: 0.000875
# Epoch: 58
# Loss: 0.000682
# Epoch: 59
# Loss: 0.003505
# Epoch: 60
# Loss: 0.000392
# Accuracy on test dataset: 90.21
# Epoch: 61
# Loss: 0.000324
# Epoch: 62
# Loss: 0.001224
# Epoch: 63
# Loss: 0.000195
# Epoch: 64
# Loss: 0.000333
# Epoch: 65
# Loss: 0.000078
# Epoch: 66
# Loss: 0.001000
# Epoch: 67
# Loss: 0.025219
# Epoch: 68
# Loss: 0.000224
# Epoch: 69
# Loss: 0.002955
# Epoch: 70
# Loss: 0.000388
# Accuracy on test dataset: 90.38
# Epoch: 71
# Loss: 0.000896
# Epoch: 72
# Loss: 0.000404
# Epoch: 73
# Loss: 0.000185
# Epoch: 74
# Loss: 0.001254
# Epoch: 75
# Loss: 0.000555
# Epoch: 76
# Loss: 0.001050
# Epoch: 77
# Loss: 0.000569
# Epoch: 78
# Loss: 0.001296
# Epoch: 79
# Loss: 0.000440
# Epoch: 80
# Loss: 0.001347
# Accuracy on test dataset: 90.24
# Epoch: 81
# Loss: 0.000876
# Epoch: 82
# Loss: 0.000070
# Epoch: 83
# Loss: 0.000191
# Epoch: 84
# Loss: 0.000300
# Epoch: 85
# Loss: 0.000103
# Epoch: 86
# Loss: 0.000051
# Epoch: 87
# Loss: 0.002017
# Epoch: 88
# Loss: 0.000075
# Epoch: 89
# Loss: 0.000078
# Epoch: 90
# Loss: 0.000579
# Accuracy on test dataset: 90.77
# Epoch: 91
# Loss: 0.000222
# Epoch: 92
# Loss: 0.000209
# Epoch: 93
# Loss: 0.006035
# Epoch: 94
# Loss: 0.000095
# Epoch: 95
# Loss: 0.001557
# Epoch: 96
# Loss: 0.013395
# Epoch: 97
# Loss: 0.000328
# Epoch: 98
# Loss: 0.001219
# Epoch: 99
# Loss: 0.000460
# Epoch: 100
# Loss: 0.000359
# Accuracy on test dataset: 90.69
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 6.060054
# Accuracy on test dataset: 6.55
# Epoch: 1
# Loss: 4.308205
# Epoch: 2
# Loss: 3.785536
# Epoch: 3
# Loss: 1.969104
# Epoch: 4
# Loss: 0.902117
# Epoch: 5
# Loss: 0.484285
# Epoch: 6
# Loss: 0.255955
# Epoch: 7
# Loss: 0.115500
# Epoch: 8
# Loss: 0.108361
# Epoch: 9
# Loss: 0.033111
# Epoch: 10
# Loss: 0.060558
# Accuracy on test dataset: 84.66
# Epoch: 11
# Loss: 0.045089
# Epoch: 12
# Loss: 0.050893
# Epoch: 13
# Loss: 0.017369
# Epoch: 14
# Loss: 0.005782
# Epoch: 15
# Loss: 0.014693
# Epoch: 16
# Loss: 0.020270
# Epoch: 17
# Loss: 0.007264
# Epoch: 18
# Loss: 0.079460
# Epoch: 19
# Loss: 0.006976
# Epoch: 20
# Loss: 0.000976
# Accuracy on test dataset: 86.75
# Epoch: 21
# Loss: 0.003114
# Epoch: 22
# Loss: 0.002922
# Epoch: 23
# Loss: 0.009768
# Epoch: 24
# Loss: 0.004310
# Epoch: 25
# Loss: 0.009488
# Epoch: 26
# Loss: 0.008676
# Epoch: 27
# Loss: 0.001420
# Epoch: 28
# Loss: 0.000876
# Epoch: 29
# Loss: 0.007332
# Epoch: 30
# Loss: 0.000397
# Accuracy on test dataset: 88.39
# Epoch: 31
# Loss: 0.002005
# Epoch: 32
# Loss: 0.001722
# Epoch: 33
# Loss: 0.000938
# Epoch: 34
# Loss: 0.002469
# Epoch: 35
# Loss: 0.002157
# Epoch: 36
# Loss: 0.001216
# Epoch: 37
# Loss: 0.001156
# Epoch: 38
# Loss: 0.001054
# Epoch: 39
# Loss: 0.001328
# Epoch: 40
# Loss: 0.001737
# Accuracy on test dataset: 89.11
# Epoch: 41
# Loss: 0.000689
# Epoch: 42
# Loss: 0.001673
# Epoch: 43
# Loss: 0.001415
# Epoch: 44
# Loss: 0.001171
# Epoch: 45
# Loss: 0.000857
# Epoch: 46
# Loss: 0.000241
# Epoch: 47
# Loss: 0.000103
# Epoch: 48
# Loss: 0.002945
# Epoch: 49
# Loss: 0.001910
# Epoch: 50
# Loss: 0.001104
# Accuracy on test dataset: 88.92
# Epoch: 51
# Loss: 0.000426
# Epoch: 52
# Loss: 0.001360
# Epoch: 53
# Loss: 0.000371
# Epoch: 54
# Loss: 0.000879
# Epoch: 55
# Loss: 0.000670
# Epoch: 56
# Loss: 0.002169
# Epoch: 57
# Loss: 0.006267
# Epoch: 58
# Loss: 0.005444
# Epoch: 59
# Loss: 0.000466
# Epoch: 60
# Loss: 0.001241
# Accuracy on test dataset: 89.45
# Epoch: 61
# Loss: 0.000432
# Epoch: 62
# Loss: 0.000809
# Epoch: 63
# Loss: 0.000303
# Epoch: 64
# Loss: 0.000349
# Epoch: 65
# Loss: 0.000362
# Epoch: 66
# Loss: 0.000087
# Epoch: 67
# Loss: 0.001120
# Epoch: 68
# Loss: 0.001946
# Epoch: 69
# Loss: 0.000530
# Epoch: 70
# Loss: 0.000418
# Accuracy on test dataset: 89.78
# Epoch: 71
# Loss: 0.000132
# Epoch: 72
# Loss: 0.000204
# Epoch: 73
# Loss: 0.000207
# Epoch: 74
# Loss: 0.000181
# Epoch: 75
# Loss: 0.000534
# Epoch: 76
# Loss: 0.002624
# Epoch: 77
# Loss: 0.000243
# Epoch: 78
# Loss: 0.000405
# Epoch: 79
# Loss: 0.000899
# Epoch: 80
# Loss: 0.004512
# Accuracy on test dataset: 89.33
# Epoch: 81
# Loss: 0.000213
# Epoch: 82
# Loss: 0.000714
# Epoch: 83
# Loss: 0.000120
# Epoch: 84
# Loss: 0.000139
# Epoch: 85
# Loss: 0.000023
# Epoch: 86
# Loss: 0.000114
# Epoch: 87
# Loss: 0.000436
# Epoch: 88
# Loss: 0.000073
# Epoch: 89
# Loss: 0.000103
# Epoch: 90
# Loss: 0.000139
# Accuracy on test dataset: 90.10
# Epoch: 91
# Loss: 0.000152
# Epoch: 92
# Loss: 0.000424
# Epoch: 93
# Loss: 0.000043
# Epoch: 94
# Loss: 0.000365
# Epoch: 95
# Loss: 0.000023
# Epoch: 96
# Loss: 0.000900
# Epoch: 97
# Loss: 0.000074
# Epoch: 98
# Loss: 0.000050
# Epoch: 99
# Loss: 0.000183
# Epoch: 100
# Loss: 0.000292
# Accuracy on test dataset: 90.52
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 5.281543
# Accuracy on test dataset: 5.86
# Epoch: 1
# Loss: 4.152488
# Epoch: 2
# Loss: 3.215022
# Epoch: 3
# Loss: 1.465517
# Epoch: 4
# Loss: 1.115472
# Epoch: 5
# Loss: 0.387103
# Epoch: 6
# Loss: 0.466753
# Epoch: 7
# Loss: 0.221327
# Epoch: 8
# Loss: 0.073024
# Epoch: 9
# Loss: 0.032224
# Epoch: 10
# Loss: 0.033932
# Accuracy on test dataset: 83.19
# Epoch: 11
# Loss: 0.011080
# Epoch: 12
# Loss: 0.017124
# Epoch: 13
# Loss: 0.010760
# Epoch: 14
# Loss: 0.005133
# Epoch: 15
# Loss: 0.008000
# Epoch: 16
# Loss: 0.009614
# Epoch: 17
# Loss: 0.005390
# Epoch: 18
# Loss: 0.011979
# Epoch: 19
# Loss: 0.024305
# Epoch: 20
# Loss: 0.010082
# Accuracy on test dataset: 85.47
# Epoch: 21
# Loss: 0.015775
# Epoch: 22
# Loss: 0.002578
# Epoch: 23
# Loss: 0.002505
# Epoch: 24
# Loss: 0.006620
# Epoch: 25
# Loss: 0.000673
# Epoch: 26
# Loss: 0.002095
# Epoch: 27
# Loss: 0.085950
# Epoch: 28
# Loss: 0.001917
# Epoch: 29
# Loss: 0.001007
# Epoch: 30
# Loss: 0.001049
# Accuracy on test dataset: 87.34
# Epoch: 31
# Loss: 0.002215
# Epoch: 32
# Loss: 0.002037
# Epoch: 33
# Loss: 0.001245
# Epoch: 34
# Loss: 0.004427
# Epoch: 35
# Loss: 0.047736
# Epoch: 36
# Loss: 0.001000
# Epoch: 37
# Loss: 0.001296
# Epoch: 38
# Loss: 0.003964
# Epoch: 39
# Loss: 0.001178
# Epoch: 40
# Loss: 0.000830
# Accuracy on test dataset: 88.34
# Epoch: 41
# Loss: 0.000532
# Epoch: 42
# Loss: 0.010138
# Epoch: 43
# Loss: 0.000774
# Epoch: 44
# Loss: 0.001641
# Epoch: 45
# Loss: 0.000319
# Epoch: 46
# Loss: 0.000901
# Epoch: 47
# Loss: 0.004645
# Epoch: 48
# Loss: 0.000173
# Epoch: 49
# Loss: 0.000424
# Epoch: 50
# Loss: 0.001570
# Accuracy on test dataset: 88.54
# Epoch: 51
# Loss: 0.000236
# Epoch: 52
# Loss: 0.000240
# Epoch: 53
# Loss: 0.000944
# Epoch: 54
# Loss: 0.001045
# Epoch: 55
# Loss: 0.004255
# Epoch: 56
# Loss: 0.000251
# Epoch: 57
# Loss: 0.000167
# Epoch: 58
# Loss: 0.000571
# Epoch: 59
# Loss: 0.000342
# Epoch: 60
# Loss: 0.000765
# Accuracy on test dataset: 87.39
# Epoch: 61
# Loss: 0.001625
# Epoch: 62
# Loss: 0.000647
# Epoch: 63
# Loss: 0.001224
# Epoch: 64
# Loss: 0.001850
# Epoch: 65
# Loss: 0.004747
# Epoch: 66
# Loss: 0.001096
# Epoch: 67
# Loss: 0.000789
# Epoch: 68
# Loss: 0.000267
# Epoch: 69
# Loss: 0.000560
# Epoch: 70
# Loss: 0.002033
# Accuracy on test dataset: 89.34
# Epoch: 71
# Loss: 0.001219
# Epoch: 72
# Loss: 0.001056
# Epoch: 73
# Loss: 0.000673
# Epoch: 74
# Loss: 0.000378
# Epoch: 75
# Loss: 0.000579
# Epoch: 76
# Loss: 0.002391
# Epoch: 77
# Loss: 0.000125
# Epoch: 78
# Loss: 0.000458
# Epoch: 79
# Loss: 0.000450
# Epoch: 80
# Loss: 0.000976
# Accuracy on test dataset: 88.46
# Epoch: 81
# Loss: 0.000212
# Epoch: 82
# Loss: 0.001070
# Epoch: 83
# Loss: 0.000816
# Epoch: 84
# Loss: 0.000450
# Epoch: 85
# Loss: 0.000624
# Epoch: 86
# Loss: 0.005684
# Epoch: 87
# Loss: 0.001393
# Epoch: 88
# Loss: 0.000112
# Epoch: 89
# Loss: 0.000310
# Epoch: 90
# Loss: 0.000971
# Accuracy on test dataset: 89.95
# Epoch: 91
# Loss: 0.000144
# Epoch: 92
# Loss: 0.000090
# Epoch: 93
# Loss: 0.000328
# Epoch: 94
# Loss: 0.000302
# Epoch: 95
# Loss: 0.000121
# Epoch: 96
# Loss: 0.000379
# Epoch: 97
# Loss: 0.000220
# Epoch: 98
# Loss: 0.000718
# Epoch: 99
# Loss: 0.000144
# Epoch: 100
# Loss: 0.000121
# Accuracy on test dataset: 90.05
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 5.744458
# Accuracy on test dataset: 8.94
# Epoch: 1
# Loss: 4.154840
# Epoch: 2
# Loss: 3.071477
# Epoch: 3
# Loss: 1.824414
# Epoch: 4
# Loss: 1.424585
# Epoch: 5
# Loss: 0.528698
# Epoch: 6
# Loss: 0.234151
# Epoch: 7
# Loss: 0.156194
# Epoch: 8
# Loss: 0.161676
# Epoch: 9
# Loss: 0.041748
# Epoch: 10
# Loss: 0.011558
# Accuracy on test dataset: 83.98
# Epoch: 11
# Loss: 0.046210
# Epoch: 12
# Loss: 0.011807
# Epoch: 13
# Loss: 0.012667
# Epoch: 14
# Loss: 0.022746
# Epoch: 15
# Loss: 0.006249
# Epoch: 16
# Loss: 0.006654
# Epoch: 17
# Loss: 0.010676
# Epoch: 18
# Loss: 0.003607
# Epoch: 19
# Loss: 0.003479
# Epoch: 20
# Loss: 0.003048
# Accuracy on test dataset: 86.50
# Epoch: 21
# Loss: 0.038501
# Epoch: 22
# Loss: 0.008350
# Epoch: 23
# Loss: 0.003996
# Epoch: 24
# Loss: 0.005972
# Epoch: 25
# Loss: 0.040390
# Epoch: 26
# Loss: 0.000810
# Epoch: 27
# Loss: 0.013102
# Epoch: 28
# Loss: 0.000797
# Epoch: 29
# Loss: 0.003280
# Epoch: 30
# Loss: 0.008768
# Accuracy on test dataset: 87.67
# Epoch: 31
# Loss: 0.013667
# Epoch: 32
# Loss: 0.013381
# Epoch: 33
# Loss: 0.001445
# Epoch: 34
# Loss: 0.049141
# Epoch: 35
# Loss: 0.001559
# Epoch: 36
# Loss: 0.000770
# Epoch: 37
# Loss: 0.003181
# Epoch: 38
# Loss: 0.002305
# Epoch: 39
# Loss: 0.000852
# Epoch: 40
# Loss: 0.000294
# Accuracy on test dataset: 88.49
# Epoch: 41
# Loss: 0.002613
# Epoch: 42
# Loss: 0.000846
# Epoch: 43
# Loss: 0.000582
# Epoch: 44
# Loss: 0.000470
# Epoch: 45
# Loss: 0.000222
# Epoch: 46
# Loss: 0.001399
# Epoch: 47
# Loss: 0.002062
# Epoch: 48
# Loss: 0.000752
# Epoch: 49
# Loss: 0.000872
# Epoch: 50
# Loss: 0.000079
# Accuracy on test dataset: 88.42
# Epoch: 51
# Loss: 0.000276
# Epoch: 52
# Loss: 0.000129
# Epoch: 53
# Loss: 0.001153
# Epoch: 54
# Loss: 0.074191
# Epoch: 55
# Loss: 0.013356
# Epoch: 56
# Loss: 0.001166
# Epoch: 57
# Loss: 0.000187
# Epoch: 58
# Loss: 0.000150
# Epoch: 59
# Loss: 0.000187
# Epoch: 60
# Loss: 0.000560
# Accuracy on test dataset: 89.21
# Epoch: 61
# Loss: 0.000640
# Epoch: 62
# Loss: 0.000684
# Epoch: 63
# Loss: 0.000471
# Epoch: 64
# Loss: 0.000059
# Epoch: 65
# Loss: 0.000270
# Epoch: 66
# Loss: 0.000156
# Epoch: 67
# Loss: 0.000067
# Epoch: 68
# Loss: 0.001331
# Epoch: 69
# Loss: 0.000210
# Epoch: 70
# Loss: 0.028327
# Accuracy on test dataset: 88.41
# Epoch: 71
# Loss: 0.001219
# Epoch: 72
# Loss: 0.001172
# Epoch: 73
# Loss: 0.000933
# Epoch: 74
# Loss: 0.000295
# Epoch: 75
# Loss: 0.004615
# Epoch: 76
# Loss: 0.000143
# Epoch: 77
# Loss: 0.000574
# Epoch: 78
# Loss: 0.000408
# Epoch: 79
# Loss: 0.039644
# Epoch: 80
# Loss: 0.000466
# Accuracy on test dataset: 90.17
# Epoch: 81
# Loss: 0.000641
# Epoch: 82
# Loss: 0.000260
# Epoch: 83
# Loss: 0.000169
# Epoch: 84
# Loss: 0.000664
# Epoch: 85
# Loss: 0.000447
# Epoch: 86
# Loss: 0.000702
# Epoch: 87
# Loss: 0.000079
# Epoch: 88
# Loss: 0.000253
# Epoch: 89
# Loss: 0.000097
# Epoch: 90
# Loss: 0.000115
# Accuracy on test dataset: 90.20
# Epoch: 91
# Loss: 0.000266
# Epoch: 92
# Loss: 0.000167
# Epoch: 93
# Loss: 0.000159
# Epoch: 94
# Loss: 0.000168
# Epoch: 95
# Loss: 0.000218
# Epoch: 96
# Loss: 0.002155
# Epoch: 97
# Loss: 0.001600
# Epoch: 98
# Loss: 0.000075
# Epoch: 99
# Loss: 0.000537
# Epoch: 100
# Loss: 0.000045
# Accuracy on test dataset: 90.24
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 5.527092
# Accuracy on test dataset: 5.51
# Epoch: 1
# Loss: 4.693129
# Epoch: 2
# Loss: 3.325691
# Epoch: 3
# Loss: 2.207204
# Epoch: 4
# Loss: 1.217222
# Epoch: 5
# Loss: 0.487311
# Epoch: 6
# Loss: 0.434774
# Epoch: 7
# Loss: 0.200773
# Epoch: 8
# Loss: 0.150306
# Epoch: 9
# Loss: 0.059764
# Epoch: 10
# Loss: 0.015827
# Accuracy on test dataset: 82.54
# Epoch: 11
# Loss: 0.031692
# Epoch: 12
# Loss: 0.007806
# Epoch: 13
# Loss: 0.210442
# Epoch: 14
# Loss: 0.010893
# Epoch: 15
# Loss: 0.012879
# Epoch: 16
# Loss: 0.002762
# Epoch: 17
# Loss: 0.021450
# Epoch: 18
# Loss: 0.014927
# Epoch: 19
# Loss: 0.007265
# Epoch: 20
# Loss: 0.003278
# Accuracy on test dataset: 86.06
# Epoch: 21
# Loss: 0.001933
# Epoch: 22
# Loss: 0.004649
# Epoch: 23
# Loss: 0.008642
# Epoch: 24
# Loss: 0.002565
# Epoch: 25
# Loss: 0.001955
# Epoch: 26
# Loss: 0.005934
# Epoch: 27
# Loss: 0.002903
# Epoch: 28
# Loss: 0.006207
# Epoch: 29
# Loss: 0.002642
# Epoch: 30
# Loss: 0.001338
# Accuracy on test dataset: 87.01
# Epoch: 31
# Loss: 0.019868
# Epoch: 32
# Loss: 0.000307
# Epoch: 33
# Loss: 0.005747
# Epoch: 34
# Loss: 0.002408
# Epoch: 35
# Loss: 0.008346
# Epoch: 36
# Loss: 0.003269
# Epoch: 37
# Loss: 0.005926
# Epoch: 38
# Loss: 0.001542
# Epoch: 39
# Loss: 0.000325
# Epoch: 40
# Loss: 0.000214
# Accuracy on test dataset: 87.81
# Epoch: 41
# Loss: 0.001323
# Epoch: 42
# Loss: 0.000880
# Epoch: 43
# Loss: 0.006128
# Epoch: 44
# Loss: 0.000414
# Epoch: 45
# Loss: 0.000729
# Epoch: 46
# Loss: 0.003576
# Epoch: 47
# Loss: 0.001619
# Epoch: 48
# Loss: 0.053517
# Epoch: 49
# Loss: 0.000871
# Epoch: 50
# Loss: 0.023347
# Accuracy on test dataset: 87.74
# Epoch: 51
# Loss: 0.002918
# Epoch: 52
# Loss: 0.000435
# Epoch: 53
# Loss: 0.000752
# Epoch: 54
# Loss: 0.008832
# Epoch: 55
# Loss: 0.008475
# Epoch: 56
# Loss: 0.000190
# Epoch: 57
# Loss: 0.000740
# Epoch: 58
# Loss: 0.000383
# Epoch: 59
# Loss: 0.000226
# Epoch: 60
# Loss: 0.000892
# Accuracy on test dataset: 88.70
# Epoch: 61
# Loss: 0.000406
# Epoch: 62
# Loss: 0.000257
# Epoch: 63
# Loss: 0.000398
# Epoch: 64
# Loss: 0.000717
# Epoch: 65
# Loss: 0.000466
# Epoch: 66
# Loss: 0.000281
# Epoch: 67
# Loss: 0.000339
# Epoch: 68
# Loss: 0.000544
# Epoch: 69
# Loss: 0.001440
# Epoch: 70
# Loss: 0.000658
# Accuracy on test dataset: 89.18
# Epoch: 71
# Loss: 0.001519
# Epoch: 72
# Loss: 0.000146
# Epoch: 73
# Loss: 0.000268
# Epoch: 74
# Loss: 0.001035
# Epoch: 75
# Loss: 0.000208
# Epoch: 76
# Loss: 0.000136
# Epoch: 77
# Loss: 0.000754
# Epoch: 78
# Loss: 0.000046
# Epoch: 79
# Loss: 0.000208
# Epoch: 80
# Loss: 0.000087
# Accuracy on test dataset: 89.67
# Epoch: 81
# Loss: 0.000044
# Epoch: 82
# Loss: 0.000390
# Epoch: 83
# Loss: 0.000419
# Epoch: 84
# Loss: 0.000245
# Epoch: 85
# Loss: 0.001071
# Epoch: 86
# Loss: 0.000151
# Epoch: 87
# Loss: 0.000196
# Epoch: 88
# Loss: 0.000102
# Epoch: 89
# Loss: 0.000145
# Epoch: 90
# Loss: 0.000544
# Accuracy on test dataset: 89.46
# Epoch: 91
# Loss: 0.000707
# Epoch: 92
# Loss: 0.000266
# Epoch: 93
# Loss: 0.000243
# Epoch: 94
# Loss: 0.000124
# Epoch: 95
# Loss: 0.000091
# Epoch: 96
# Loss: 0.000076
# Epoch: 97
# Loss: 0.001016
# Epoch: 98
# Loss: 0.000464
# Epoch: 99
# Loss: 0.000033
# Epoch: 100
# Loss: 0.000133
# Accuracy on test dataset: 89.72
# ------------------------------------------------

# %%
accuracies = np.array(accuracies)
print(f"Test accuracy on dual-domain: avg -> {np.mean(accuracies)*100:.1f}, std -> {np.std(accuracies)*100:.1f}")
# Out:
# Test accuracy on dual-domain: avg -> 90.4, std -> 0.4
