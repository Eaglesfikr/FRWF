# %% [markdown]
# # Dual-Domain (Time + Freq) Fine-tuning — Sinkhorn Pretrained
#
# Based on the **Sinkhorn** dual-domain SupCon pretrained model.
# Uses `WFTFC_dualsupcon_sinkhorn_epoch_80.pth.tar` checkpoint.
#
# N defines the number of labeled samples per class for fine-tuning.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import warnings
warnings.filterwarnings('ignore')
import numpy as np

from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import RandomSampler, SequentialSampler
import torch
from torch import nn
import torch.nn.functional as F
from torch import optim
from torch.autograd import Variable
import tqdm
import pickle
import argparse
from torch.cuda.amp import GradScaler, autocast

import random
import sys
import os
import collections
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## GPU Allocation

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu", 0)
kwargs = {'num_workers': 0, 'pin_memory': True} if use_cuda else {}
print(f'Device: {device}')
# Out:
# Device: cuda:0

# %% [markdown]
# ## Parameters

# %%
batch_size = 16

# %% [markdown]
# ## Loading the Fine-tuning Datasets
#
# Load both time domain and frequency domain data. Must be aligned.

# %%
DATASET = 'AWF'

if DATASET == 'AWF':
    # --- 时域数据 ---
    data_time = np.load('./datasets/awf2.npz')
    print('Time files:', data_time.files)
    x_time_total = data_time['data']
    y_total = data_time['labels']

    # --- 频域数据 ---
    data_freq = np.load('./datasets/awf2_freq.npz')
    print('Freq files:', data_freq.files)
    x_freq_total = data_freq['x']

print(f"Time shape: {x_time_total.shape}")
print(f"Freq shape: {x_freq_total.shape}")
print(f"Labels: {y_total.shape}")
assert len(x_time_total) == len(x_freq_total) == len(y_total), "Mismatched sample counts!"

num_classes = len(np.unique(y_total))
print(f"Number of classes: {num_classes}")
# Out:
# Time files: ['data', 'labels']
# Freq files: ['x', 'y']
# Time shape: (257500, 5000)
# Freq shape: (257500, 2500)
# Labels: (257500,)
# Number of classes: 103

# %%
# 训练/测试拆分（保持时域和频域的对齐）
x_time_train, x_time_test, x_freq_train, x_freq_test, y_train, y_test = train_test_split(
    x_time_total, x_freq_total, y_total, test_size=0.2, random_state=42, stratify=y_total)

print(f"Train: time {x_time_train.shape}, freq {x_freq_train.shape}, y {y_train.shape}")
print(f"Test:  time {x_time_test.shape}, freq {x_freq_test.shape}, y {y_test.shape}")
# Out:
# Train: time (206000, 5000), freq (206000, 2500), y (206000,)
# Test:  time (51500, 5000), freq (51500, 2500), y (51500,)

# %%
# 每个类别随机采样 N 个样本用于微调
def sample_traces(x_time, x_freq, y, N):
    train_index = []
    for c in range(num_classes):
        idx = np.where(y == c)[0]
        idx = np.random.choice(idx, min(N, len(idx)), False)
        train_index.extend(idx)
    train_index = np.array(train_index)
    np.random.shuffle(train_index)

    return x_time[train_index], x_freq[train_index], y[train_index]

# %% [markdown]
# ## Backbone Model
#
# Same DFNet as used in pretrain.

# %%
class DFNet(nn.Module):
    def __init__(self, out_dim, input_feature_dim):
        super(DFNet, self).__init__()
        kernel_size = 8
        conv_stride = 1
        pool_stride = 4
        pool_size = 8

        self.conv1 = nn.Conv1d(1, 32, kernel_size, stride=conv_stride)
        self.conv1_1 = nn.Conv1d(32, 32, kernel_size, stride=conv_stride)
        self.conv2 = nn.Conv1d(32, 64, kernel_size, stride=conv_stride)
        self.conv2_2 = nn.Conv1d(64, 64, kernel_size, stride=conv_stride)
        self.conv3 = nn.Conv1d(64, 128, kernel_size, stride=conv_stride)
        self.conv3_3 = nn.Conv1d(128, 128, kernel_size, stride=conv_stride)
        self.conv4 = nn.Conv1d(128, 256, kernel_size, stride=conv_stride)
        self.conv4_4 = nn.Conv1d(256, 256, kernel_size, stride=conv_stride)

        self.batch_norm1 = nn.BatchNorm1d(32)
        self.batch_norm2 = nn.BatchNorm1d(64)
        self.batch_norm3 = nn.BatchNorm1d(128)
        self.batch_norm4 = nn.BatchNorm1d(256)

        self.max_pool_1 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)
        self.max_pool_2 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)
        self.max_pool_3 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)
        self.max_pool_4 = nn.MaxPool1d(kernel_size=pool_size, stride=pool_stride)

        self.dropout1 = nn.Dropout(p=0.1)
        self.dropout2 = nn.Dropout(p=0.1)
        self.dropout3 = nn.Dropout(p=0.1)
        self.dropout4 = nn.Dropout(p=0.1)

        # 动态计算展平后的维度
        with torch.no_grad():
            dummy_input = torch.zeros(1, 1, input_feature_dim)
            out = self._forward_features(dummy_input)
            flattened_dim = out.view(1, -1).size(1)

        self.fc = nn.Linear(flattened_dim, out_dim)
        self.weight_init()

    def _forward_features(self, x):
        x = F.pad(x, (3,4))
        x = F.elu((self.conv1(x)))
        x = F.pad(x, (3,4))
        x = F.elu(self.batch_norm1(self.conv1_1(x)))
        x = F.pad(x, (3, 4))
        x = self.max_pool_1(x)
        x = self.dropout1(x)

        x = F.pad(x, (3,4))
        x = F.relu((self.conv2(x)))
        x = F.pad(x, (3,4))
        x = F.relu(self.batch_norm2(self.conv2_2(x)))
        x = F.pad(x, (3,4))
        x = self.max_pool_2(x)
        x = self.dropout2(x)

        x = F.pad(x, (3,4))
        x = F.relu((self.conv3(x)))
        x = F.pad(x, (3,4))
        x = F.relu(self.batch_norm3(self.conv3_3(x)))
        x = F.pad(x, (3,4))
        x = self.max_pool_3(x)
        x = self.dropout3(x)

        x = F.pad(x, (3,4))
        x = F.relu((self.conv4(x)))
        x = F.pad(x, (3,4))
        x = F.relu(self.batch_norm4(self.conv4_4(x)))
        x = F.pad(x, (3,4))
        x = self.max_pool_4(x)
        x = self.dropout4(x)
        return x

    def weight_init(self):
        for n, m in self.named_modules():
            if isinstance(m, nn.Linear) or isinstance(m, nn.Conv1d):
                torch.nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    m.bias.data.zero_()

    def forward(self, inp):
        x = self._forward_features(inp)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Dual-Domain Classifier (for finetuning)
#
# Uses both time_encoder and freq_encoder from the pretrained Sinkhorn SupCon model.
# Concatenates their 512-dim outputs → 1024-dim → classifier head.

# %%
class DualDomainClassifier(nn.Module):
    def __init__(self, time_encoder, freq_encoder, num_classes):
        super().__init__()
        self.time_encoder = time_encoder
        self.freq_encoder = freq_encoder
        self.classifier = nn.Linear(1024, num_classes)

    def forward(self, x_time, x_freq):
        h_time = self.time_encoder(x_time)
        h_freq = self.freq_encoder(x_freq)
        out = torch.cat([h_time, h_freq], dim=1)
        return self.classifier(out)

# %% [markdown]
# ## Data Loader
#
# Returns aligned (time, freq, label) tuples.

# %%
class DualData(Dataset):
    def __init__(self, x_time, x_freq, y):
        self.x_time = x_time
        self.x_freq = x_freq
        self.y = y

    def __getitem__(self, index):
        return self.x_time[index], self.x_freq[index], self.y[index]

    def __len__(self):
        return len(self.y)

# %% [markdown]
# ## Loading the Pre-trained Sinkhorn Dual-Domain Model
#
# We load the Sinkhorn SupCon pretrained `time_encoder` and `freq_encoder` weights,
# skip the projectors, and add a new classifier head.
#
# **注意**: 使用 Sinkhorn 预训练 checkpoint (`WFTFC_dualsupcon_sinkhorn_epoch_80.pth.tar`)。
# encoder 的 fc 维度 (512) 和 finetune 一致，所以包含 fc 层一起加载。
# 只跳过 `time_projector.*` / `freq_projector.*` 的投影头权重。

# %%
def load_checkpoint():
    """
    Load Sinkhorn dual-domain SupCon pretrained model.
    Extract time_encoder and freq_encoder weights, skip projectors.
    """
    time_input_dim = x_time_train.shape[1]  # 5000
    freq_input_dim = x_freq_train.shape[1]   # 2500

    # 创建两个 encoder（和 pretrain 结构完全一致）
    time_encoder = DFNet(out_dim=512, input_feature_dim=time_input_dim)
    freq_encoder = DFNet(out_dim=512, input_feature_dim=freq_input_dim)

    # ===== 加载 Sinkhorn dual-domain checkpoint =====
    # 注意: pretrain-sinkhorn 只保存到 epoch 80，这里加载最后一版
    checkpoint = torch.load('./checkpoints/WFTFC/WFTFC_dualsupcon_sinkhorn_epoch_80.pth.tar')

    # 提取 time_encoder 权重
    time_state = {}
    for k, v in checkpoint.items():
        if k.startswith('time_encoder.'):
            new_k = k[len('time_encoder.'):]
            time_state[new_k] = v

    # 提取 freq_encoder 权重
    freq_state = {}
    for k, v in checkpoint.items():
        if k.startswith('freq_encoder.'):
            new_k = k[len('freq_encoder.'):]
            freq_state[new_k] = v

    # 加载 encoder 权重（fc 维度一致，全部加载）
    log_t = time_encoder.load_state_dict(time_state, strict=False)
    log_f = freq_encoder.load_state_dict(freq_state, strict=False)
    print(f"Time encoder missing: {log_t.missing_keys}")
    print(f"Freq encoder missing: {log_f.missing_keys}")

    # 组装分类器
    model = DualDomainClassifier(time_encoder, freq_encoder, num_classes).to(device)
    return model

# %% [markdown]
# ## Init Test Data Loaders

# %%
test_dataset = DualData(x_time_test, x_freq_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, drop_last=True)

# %% [markdown]
# ## Train and Test Functions
#
# Both take `(x_time, x_freq, target)` instead of just `(data, target)`.

# %%
def train(model, device, train_loader, optimizer):
    model.train()
    for batch_idx, (x_time, x_freq, target) in enumerate(train_loader):
        x_time = x_time.view(x_time.size(0), 1, x_time.size(1)).float().to(device)
        x_freq = x_freq.view(x_freq.size(0), 1, x_freq.size(1)).float().to(device)
        target = target.to(device).long()

        optimizer.zero_grad()
        output = model(x_time, x_freq)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print(f"Loss: {loss.item():.6f}")

def test(model, device, loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for x_time, x_freq, target in loader:
            x_time = x_time.view(x_time.size(0), 1, x_time.size(1)).float().to(device)
            x_freq = x_freq.view(x_freq.size(0), 1, x_freq.size(1)).float().to(device)
            target = target.to(device).long()

            output = model(x_time, x_freq)
            output = torch.softmax(output, dim=1)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).float().sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ## Running for 5 Times

# %%
# N defines the number of labeled samples per class for fine-tuning
N = 5

# %%
accuracies = []
for _ in range(5):
    x_time_ft, x_freq_ft, y_ft = sample_traces(x_time_train, x_freq_train, y_train, N)
    print(f"Input size: time {x_time_ft.shape}, freq {x_freq_ft.shape}, y {y_ft.shape}")

    train_dataset = DualData(x_time_ft, x_freq_ft, y_ft)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

    model = load_checkpoint()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    best_acc = 0
    for epoch in range(101):
        print(f"Epoch: {epoch}")
        train(model, device, train_loader, optimizer)

        acc = test(model, device, test_loader)
        best_acc = max(best_acc, acc)

        if epoch % 10 == 0:
            print(f"Accuracy on test dataset: {acc*100:.2f}")

    accuracies.append(best_acc)
    print('------------------------------------------------')
# Out:
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 5.608017
# Accuracy on test dataset: 7.16
# Epoch: 1
# Loss: 3.828770
# Epoch: 2
# Loss: 2.772758
# Epoch: 3
# Loss: 1.922414
# Epoch: 4
# Loss: 0.854344
# Epoch: 5
# Loss: 0.956308
# Epoch: 6
# Loss: 0.389188
# Epoch: 7
# Loss: 0.077553
# Epoch: 8
# Loss: 0.072019
# Epoch: 9
# Loss: 0.021553
# Epoch: 10
# Loss: 0.016399
# Accuracy on test dataset: 83.08
# Epoch: 11
# Loss: 0.032163
# Epoch: 12
# Loss: 0.027402
# Epoch: 13
# Loss: 0.021555
# Epoch: 14
# Loss: 0.004032
# Epoch: 15
# Loss: 0.009296
# Epoch: 16
# Loss: 0.010877
# Epoch: 17
# Loss: 0.013387
# Epoch: 18
# Loss: 0.010083
# Epoch: 19
# Loss: 0.004244
# Epoch: 20
# Loss: 0.024606
# Accuracy on test dataset: 85.29
# Epoch: 21
# Loss: 0.004808
# Epoch: 22
# Loss: 0.001671
# Epoch: 23
# Loss: 0.001287
# Epoch: 24
# Loss: 0.006156
# Epoch: 25
# Loss: 0.012027
# Epoch: 26
# Loss: 0.001558
# Epoch: 27
# Loss: 0.000985
# Epoch: 28
# Loss: 0.001842
# Epoch: 29
# Loss: 0.001115
# Epoch: 30
# Loss: 0.001061
# Accuracy on test dataset: 86.66
# Epoch: 31
# Loss: 0.004688
# Epoch: 32
# Loss: 0.001123
# Epoch: 33
# Loss: 0.000523
# Epoch: 34
# Loss: 0.002164
# Epoch: 35
# Loss: 0.004433
# Epoch: 36
# Loss: 0.000611
# Epoch: 37
# Loss: 0.001024
# Epoch: 38
# Loss: 0.003934
# Epoch: 39
# Loss: 0.005567
# Epoch: 40
# Loss: 0.000359
# Accuracy on test dataset: 87.48
# Epoch: 41
# Loss: 0.000071
# Epoch: 42
# Loss: 0.000381
# Epoch: 43
# Loss: 0.000230
# Epoch: 44
# Loss: 0.000425
# Epoch: 45
# Loss: 0.000948
# Epoch: 46
# Loss: 0.000209
# Epoch: 47
# Loss: 0.002831
# Epoch: 48
# Loss: 0.000637
# Epoch: 49
# Loss: 0.008792
# Epoch: 50
# Loss: 0.001314
# Accuracy on test dataset: 88.00
# Epoch: 51
# Loss: 0.000646
# Epoch: 52
# Loss: 0.000321
# Epoch: 53
# Loss: 0.000104
# Epoch: 54
# Loss: 0.000327
# Epoch: 55
# Loss: 0.000209
# Epoch: 56
# Loss: 0.000462
# Epoch: 57
# Loss: 0.000876
# Epoch: 58
# Loss: 0.000852
# Epoch: 59
# Loss: 0.000243
# Epoch: 60
# Loss: 0.000203
# Accuracy on test dataset: 88.45
# Epoch: 61
# Loss: 0.000213
# Epoch: 62
# Loss: 0.000353
# Epoch: 63
# Loss: 0.000206
# Epoch: 64
# Loss: 0.000219
# Epoch: 65
# Loss: 0.000234
# Epoch: 66
# Loss: 0.000238
# Epoch: 67
# Loss: 0.000282
# Epoch: 68
# Loss: 0.000247
# Epoch: 69
# Loss: 0.000201
# Epoch: 70
# Loss: 0.000060
# Accuracy on test dataset: 88.49
# Epoch: 71
# Loss: 0.000934
# Epoch: 72
# Loss: 0.000207
# Epoch: 73
# Loss: 0.001529
# Epoch: 74
# Loss: 0.000244
# Epoch: 75
# Loss: 0.000051
# Epoch: 76
# Loss: 0.000257
# Epoch: 77
# Loss: 0.000093
# Epoch: 78
# Loss: 0.000047
# Epoch: 79
# Loss: 0.000131
# Epoch: 80
# Loss: 0.000074
# Accuracy on test dataset: 88.90
# Epoch: 81
# Loss: 0.000598
# Epoch: 82
# Loss: 0.000159
# Epoch: 83
# Loss: 0.000071
# Epoch: 84
# Loss: 0.000025
# Epoch: 85
# Loss: 0.000143
# Epoch: 86
# Loss: 0.000017
# Epoch: 87
# Loss: 0.000083
# Epoch: 88
# Loss: 0.000122
# Epoch: 89
# Loss: 0.000767
# Epoch: 90
# Loss: 0.000027
# Accuracy on test dataset: 88.89
# Epoch: 91
# Loss: 0.000327
# Epoch: 92
# Loss: 0.000168
# Epoch: 93
# Loss: 0.000241
# Epoch: 94
# Loss: 0.000090
# Epoch: 95
# Loss: 0.001634
# Epoch: 96
# Loss: 0.000107
# Epoch: 97
# Loss: 0.002364
# Epoch: 98
# Loss: 0.000252
# Epoch: 99
# Loss: 0.000095
# Epoch: 100
# Loss: 0.000103
# Accuracy on test dataset: 89.42
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 5.809378
# Accuracy on test dataset: 6.17
# Epoch: 1
# Loss: 4.492079
# Epoch: 2
# Loss: 3.001383
# Epoch: 3
# Loss: 2.049725
# Epoch: 4
# Loss: 0.891509
# Epoch: 5
# Loss: 0.204087
# Epoch: 6
# Loss: 0.269226
# Epoch: 7
# Loss: 0.111702
# Epoch: 8
# Loss: 0.042051
# Epoch: 9
# Loss: 0.073495
# Epoch: 10
# Loss: 0.009841
# Accuracy on test dataset: 84.05
# Epoch: 11
# Loss: 0.046875
# Epoch: 12
# Loss: 0.006918
# Epoch: 13
# Loss: 0.024901
# Epoch: 14
# Loss: 0.010085
# Epoch: 15
# Loss: 0.011066
# Epoch: 16
# Loss: 0.014487
# Epoch: 17
# Loss: 0.002091
# Epoch: 18
# Loss: 0.009374
# Epoch: 19
# Loss: 0.078657
# Epoch: 20
# Loss: 0.005783
# Accuracy on test dataset: 85.53
# Epoch: 21
# Loss: 0.025951
# Epoch: 22
# Loss: 0.001382
# Epoch: 23
# Loss: 0.001461
# Epoch: 24
# Loss: 0.003311
# Epoch: 25
# Loss: 0.012923
# Epoch: 26
# Loss: 0.001267
# Epoch: 27
# Loss: 0.001651
# Epoch: 28
# Loss: 0.001490
# Epoch: 29
# Loss: 0.001236
# Epoch: 30
# Loss: 0.002429
# Accuracy on test dataset: 87.66
# Epoch: 31
# Loss: 0.001534
# Epoch: 32
# Loss: 0.000707
# Epoch: 33
# Loss: 0.001075
# Epoch: 34
# Loss: 0.001692
# Epoch: 35
# Loss: 0.001442
# Epoch: 36
# Loss: 0.000473
# Epoch: 37
# Loss: 0.000756
# Epoch: 38
# Loss: 0.001054
# Epoch: 39
# Loss: 0.000828
# Epoch: 40
# Loss: 0.001021
# Accuracy on test dataset: 88.15
# Epoch: 41
# Loss: 0.003973
# Epoch: 42
# Loss: 0.000863
# Epoch: 43
# Loss: 0.002236
# Epoch: 44
# Loss: 0.001079
# Epoch: 45
# Loss: 0.001123
# Epoch: 46
# Loss: 0.000634
# Epoch: 47
# Loss: 0.001127
# Epoch: 48
# Loss: 0.000209
# Epoch: 49
# Loss: 0.006284
# Epoch: 50
# Loss: 0.000727
# Accuracy on test dataset: 88.83
# Epoch: 51
# Loss: 0.002514
# Epoch: 52
# Loss: 0.000715
# Epoch: 53
# Loss: 0.003297
# Epoch: 54
# Loss: 0.000566
# Epoch: 55
# Loss: 0.000458
# Epoch: 56
# Loss: 0.000543
# Epoch: 57
# Loss: 0.000144
# Epoch: 58
# Loss: 0.000443
# Epoch: 59
# Loss: 0.000057
# Epoch: 60
# Loss: 0.000460
# Accuracy on test dataset: 88.66
# Epoch: 61
# Loss: 0.000114
# Epoch: 62
# Loss: 0.000196
# Epoch: 63
# Loss: 0.000084
# Epoch: 64
# Loss: 0.000296
# Epoch: 65
# Loss: 0.000277
# Epoch: 66
# Loss: 0.000065
# Epoch: 67
# Loss: 0.000526
# Epoch: 68
# Loss: 0.000165
# Epoch: 69
# Loss: 0.001401
# Epoch: 70
# Loss: 0.000123
# Accuracy on test dataset: 89.63
# Epoch: 71
# Loss: 0.000162
# Epoch: 72
# Loss: 0.000258
# Epoch: 73
# Loss: 0.000091
# Epoch: 74
# Loss: 0.000170
# Epoch: 75
# Loss: 0.000623
# Epoch: 76
# Loss: 0.000107
# Epoch: 77
# Loss: 0.000089
# Epoch: 78
# Loss: 0.000102
# Epoch: 79
# Loss: 0.000165
# Epoch: 80
# Loss: 0.000419
# Accuracy on test dataset: 89.57
# Epoch: 81
# Loss: 0.000067
# Epoch: 82
# Loss: 0.000566
# Epoch: 83
# Loss: 0.000047
# Epoch: 84
# Loss: 0.000048
# Epoch: 85
# Loss: 0.000180
# Epoch: 86
# Loss: 0.000074
# Epoch: 87
# Loss: 0.000032
# Epoch: 88
# Loss: 0.000034
# Epoch: 89
# Loss: 0.000241
# Epoch: 90
# Loss: 0.000339
# Accuracy on test dataset: 90.05
# Epoch: 91
# Loss: 0.000114
# Epoch: 92
# Loss: 0.000157
# Epoch: 93
# Loss: 0.000034
# Epoch: 94
# Loss: 0.000800
# Epoch: 95
# Loss: 0.000051
# Epoch: 96
# Loss: 0.000027
# Epoch: 97
# Loss: 0.002891
# Epoch: 98
# Loss: 0.008612
# Epoch: 99
# Loss: 0.003999
# Epoch: 100
# Loss: 0.002157
# Accuracy on test dataset: 89.17
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 6.887186
# Accuracy on test dataset: 7.26
# Epoch: 1
# Loss: 4.269430
# Epoch: 2
# Loss: 3.042126
# Epoch: 3
# Loss: 1.974441
# Epoch: 4
# Loss: 0.845575
# Epoch: 5
# Loss: 0.450309
# Epoch: 6
# Loss: 0.497865
# Epoch: 7
# Loss: 0.198715
# Epoch: 8
# Loss: 0.059890
# Epoch: 9
# Loss: 0.061690
# Epoch: 10
# Loss: 0.022131
# Accuracy on test dataset: 83.77
# Epoch: 11
# Loss: 0.076488
# Epoch: 12
# Loss: 0.044305
# Epoch: 13
# Loss: 0.014103
# Epoch: 14
# Loss: 0.026333
# Epoch: 15
# Loss: 0.006016
# Epoch: 16
# Loss: 0.004832
# Epoch: 17
# Loss: 0.003071
# Epoch: 18
# Loss: 0.011290
# Epoch: 19
# Loss: 0.001079
# Epoch: 20
# Loss: 0.009948
# Accuracy on test dataset: 86.29
# Epoch: 21
# Loss: 0.005980
# Epoch: 22
# Loss: 0.004285
# Epoch: 23
# Loss: 0.019776
# Epoch: 24
# Loss: 0.000739
# Epoch: 25
# Loss: 0.002062
# Epoch: 26
# Loss: 0.005525
# Epoch: 27
# Loss: 0.004471
# Epoch: 28
# Loss: 0.002457
# Epoch: 29
# Loss: 0.003733
# Epoch: 30
# Loss: 0.000641
# Accuracy on test dataset: 87.12
# Epoch: 31
# Loss: 0.000754
# Epoch: 32
# Loss: 0.000501
# Epoch: 33
# Loss: 0.000929
# Epoch: 34
# Loss: 0.000273
# Epoch: 35
# Loss: 0.003016
# Epoch: 36
# Loss: 0.004950
# Epoch: 37
# Loss: 0.000923
# Epoch: 38
# Loss: 0.001173
# Epoch: 39
# Loss: 0.001146
# Epoch: 40
# Loss: 0.002033
# Accuracy on test dataset: 87.90
# Epoch: 41
# Loss: 0.001158
# Epoch: 42
# Loss: 0.000449
# Epoch: 43
# Loss: 0.000791
# Epoch: 44
# Loss: 0.001218
# Epoch: 45
# Loss: 0.002885
# Epoch: 46
# Loss: 0.001993
# Epoch: 47
# Loss: 0.000404
# Epoch: 48
# Loss: 0.000740
# Epoch: 49
# Loss: 0.002694
# Epoch: 50
# Loss: 0.000428
# Accuracy on test dataset: 88.14
# Epoch: 51
# Loss: 0.000535
# Epoch: 52
# Loss: 0.000110
# Epoch: 53
# Loss: 0.000363
# Epoch: 54
# Loss: 0.000669
# Epoch: 55
# Loss: 0.000740
# Epoch: 56
# Loss: 0.000440
# Epoch: 57
# Loss: 0.000343
# Epoch: 58
# Loss: 0.000733
# Epoch: 59
# Loss: 0.000674
# Epoch: 60
# Loss: 0.001304
# Accuracy on test dataset: 88.22
# Epoch: 61
# Loss: 0.002069
# Epoch: 62
# Loss: 0.000057
# Epoch: 63
# Loss: 0.000319
# Epoch: 64
# Loss: 0.000448
# Epoch: 65
# Loss: 0.000131
# Epoch: 66
# Loss: 0.000681
# Epoch: 67
# Loss: 0.000509
# Epoch: 68
# Loss: 0.000144
# Epoch: 69
# Loss: 0.000558
# Epoch: 70
# Loss: 0.000105
# Accuracy on test dataset: 88.42
# Epoch: 71
# Loss: 0.000163
# Epoch: 72
# Loss: 0.000236
# Epoch: 73
# Loss: 0.000053
# Epoch: 74
# Loss: 0.000145
# Epoch: 75
# Loss: 0.000248
# Epoch: 76
# Loss: 0.001146
# Epoch: 77
# Loss: 0.000262
# Epoch: 78
# Loss: 0.000095
# Epoch: 79
# Loss: 0.000093
# Epoch: 80
# Loss: 0.000126
# Accuracy on test dataset: 88.80
# Epoch: 81
# Loss: 0.000091
# Epoch: 82
# Loss: 0.000068
# Epoch: 83
# Loss: 0.000254
# Epoch: 84
# Loss: 0.000091
# Epoch: 85
# Loss: 0.004059
# Epoch: 86
# Loss: 0.000056
# Epoch: 87
# Loss: 0.000302
# Epoch: 88
# Loss: 0.000092
# Epoch: 89
# Loss: 0.000219
# Epoch: 90
# Loss: 0.000132
# Accuracy on test dataset: 88.53
# Epoch: 91
# Loss: 0.000237
# Epoch: 92
# Loss: 0.000316
# Epoch: 93
# Loss: 0.000155
# Epoch: 94
# Loss: 0.000147
# Epoch: 95
# Loss: 0.000108
# Epoch: 96
# Loss: 0.000351
# Epoch: 97
# Loss: 0.000105
# Epoch: 98
# Loss: 0.000514
# Epoch: 99
# Loss: 0.001132
# Epoch: 100
# Loss: 0.000694
# Accuracy on test dataset: 88.90
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 5.267478
# Accuracy on test dataset: 7.81
# Epoch: 1
# Loss: 4.365801
# Epoch: 2
# Loss: 2.467810
# Epoch: 3
# Loss: 1.931751
# Epoch: 4
# Loss: 0.957993
# Epoch: 5
# Loss: 0.241207
# Epoch: 6
# Loss: 0.093505
# Epoch: 7
# Loss: 0.070338
# Epoch: 8
# Loss: 0.054405
# Epoch: 9
# Loss: 0.030621
# Epoch: 10
# Loss: 0.018023
# Accuracy on test dataset: 84.46
# Epoch: 11
# Loss: 0.022556
# Epoch: 12
# Loss: 0.077333
# Epoch: 13
# Loss: 0.029879
# Epoch: 14
# Loss: 0.017929
# Epoch: 15
# Loss: 0.013872
# Epoch: 16
# Loss: 0.041316
# Epoch: 17
# Loss: 0.010012
# Epoch: 18
# Loss: 0.005334
# Epoch: 19
# Loss: 0.008565
# Epoch: 20
# Loss: 0.001736
# Accuracy on test dataset: 86.25
# Epoch: 21
# Loss: 0.008854
# Epoch: 22
# Loss: 0.001965
# Epoch: 23
# Loss: 0.031068
# Epoch: 24
# Loss: 0.003495
# Epoch: 25
# Loss: 0.001823
# Epoch: 26
# Loss: 0.004072
# Epoch: 27
# Loss: 0.000768
# Epoch: 28
# Loss: 0.002122
# Epoch: 29
# Loss: 0.000805
# Epoch: 30
# Loss: 0.001842
# Accuracy on test dataset: 87.50
# Epoch: 31
# Loss: 0.001471
# Epoch: 32
# Loss: 0.000595
# Epoch: 33
# Loss: 0.001743
# Epoch: 34
# Loss: 0.000416
# Epoch: 35
# Loss: 0.001449
# Epoch: 36
# Loss: 0.000769
# Epoch: 37
# Loss: 0.000342
# Epoch: 38
# Loss: 0.004577
# Epoch: 39
# Loss: 0.000305
# Epoch: 40
# Loss: 0.001006
# Accuracy on test dataset: 88.13
# Epoch: 41
# Loss: 0.001660
# Epoch: 42
# Loss: 0.000239
# Epoch: 43
# Loss: 0.000435
# Epoch: 44
# Loss: 0.000669
# Epoch: 45
# Loss: 0.001356
# Epoch: 46
# Loss: 0.001162
# Epoch: 47
# Loss: 0.000799
# Epoch: 48
# Loss: 0.000170
# Epoch: 49
# Loss: 0.000352
# Epoch: 50
# Loss: 0.000988
# Accuracy on test dataset: 88.37
# Epoch: 51
# Loss: 0.000323
# Epoch: 52
# Loss: 0.000344
# Epoch: 53
# Loss: 0.000315
# Epoch: 54
# Loss: 0.000305
# Epoch: 55
# Loss: 0.000371
# Epoch: 56
# Loss: 0.000106
# Epoch: 57
# Loss: 0.000178
# Epoch: 58
# Loss: 0.000179
# Epoch: 59
# Loss: 0.000191
# Epoch: 60
# Loss: 0.000157
# Accuracy on test dataset: 88.61
# Epoch: 61
# Loss: 0.000441
# Epoch: 62
# Loss: 0.007495
# Epoch: 63
# Loss: 0.001126
# Epoch: 64
# Loss: 0.001490
# Epoch: 65
# Loss: 0.000500
# Epoch: 66
# Loss: 0.000177
# Epoch: 67
# Loss: 0.003274
# Epoch: 68
# Loss: 0.000579
# Epoch: 69
# Loss: 0.000338
# Epoch: 70
# Loss: 0.001078
# Accuracy on test dataset: 88.92
# Epoch: 71
# Loss: 0.000213
# Epoch: 72
# Loss: 0.005535
# Epoch: 73
# Loss: 0.000317
# Epoch: 74
# Loss: 0.000305
# Epoch: 75
# Loss: 0.000140
# Epoch: 76
# Loss: 0.000125
# Epoch: 77
# Loss: 0.000436
# Epoch: 78
# Loss: 0.000642
# Epoch: 79
# Loss: 0.000187
# Epoch: 80
# Loss: 0.000149
# Accuracy on test dataset: 89.09
# Epoch: 81
# Loss: 0.000300
# Epoch: 82
# Loss: 0.000121
# Epoch: 83
# Loss: 0.000230
# Epoch: 84
# Loss: 0.001549
# Epoch: 85
# Loss: 0.000438
# Epoch: 86
# Loss: 0.000162
# Epoch: 87
# Loss: 0.000180
# Epoch: 88
# Loss: 0.000155
# Epoch: 89
# Loss: 0.000291
# Epoch: 90
# Loss: 0.000474
# Accuracy on test dataset: 89.54
# Epoch: 91
# Loss: 0.000281
# Epoch: 92
# Loss: 0.000083
# Epoch: 93
# Loss: 0.000611
# Epoch: 94
# Loss: 0.000136
# Epoch: 95
# Loss: 0.000174
# Epoch: 96
# Loss: 0.000099
# Epoch: 97
# Loss: 0.000117
# Epoch: 98
# Loss: 0.000067
# Epoch: 99
# Loss: 0.000144
# Epoch: 100
# Loss: 0.000040
# Accuracy on test dataset: 89.85
# ------------------------------------------------
# Input size: time (515, 5000), freq (515, 2500), y (515,)
# Time encoder missing: []
# Freq encoder missing: []
# Epoch: 0
# Loss: 5.239575
# Accuracy on test dataset: 10.09
# Epoch: 1
# Loss: 3.556103
# Epoch: 2
# Loss: 3.691341
# Epoch: 3
# Loss: 2.291827
# Epoch: 4
# Loss: 1.565798
# Epoch: 5
# Loss: 0.462739
# Epoch: 6
# Loss: 0.075099
# Epoch: 7
# Loss: 0.103374
# Epoch: 8
# Loss: 0.035026
# Epoch: 9
# Loss: 0.081906
# Epoch: 10
# Loss: 0.060055
# Accuracy on test dataset: 83.84
# Epoch: 11
# Loss: 0.021923
# Epoch: 12
# Loss: 0.014975
# Epoch: 13
# Loss: 0.018651
# Epoch: 14
# Loss: 0.012765
# Epoch: 15
# Loss: 0.028669
# Epoch: 16
# Loss: 0.004719
# Epoch: 17
# Loss: 0.065741
# Epoch: 18
# Loss: 0.002179
# Epoch: 19
# Loss: 0.008002
# Epoch: 20
# Loss: 0.008244
# Accuracy on test dataset: 86.71
# Epoch: 21
# Loss: 0.011050
# Epoch: 22
# Loss: 0.003164
# Epoch: 23
# Loss: 0.002401
# Epoch: 24
# Loss: 0.001396
# Epoch: 25
# Loss: 0.004167
# Epoch: 26
# Loss: 0.011530
# Epoch: 27
# Loss: 0.002285
# Epoch: 28
# Loss: 0.004313
# Epoch: 29
# Loss: 0.002918
# Epoch: 30
# Loss: 0.003082
# Accuracy on test dataset: 87.82
# Epoch: 31
# Loss: 0.008261
# Epoch: 32
# Loss: 0.001615
# Epoch: 33
# Loss: 0.000742
# Epoch: 34
# Loss: 0.000971
# Epoch: 35
# Loss: 0.008698
# Epoch: 36
# Loss: 0.000945
# Epoch: 37
# Loss: 0.000664
# Epoch: 38
# Loss: 0.004727
# Epoch: 39
# Loss: 0.021963
# Epoch: 40
# Loss: 0.001101
# Accuracy on test dataset: 88.32
# Epoch: 41
# Loss: 0.002676
# Epoch: 42
# Loss: 0.000477
# Epoch: 43
# Loss: 0.014475
# Epoch: 44
# Loss: 0.000290
# Epoch: 45
# Loss: 0.000213
# Epoch: 46
# Loss: 0.000780
# Epoch: 47
# Loss: 0.000437
# Epoch: 48
# Loss: 0.000500
# Epoch: 49
# Loss: 0.000817
# Epoch: 50
# Loss: 0.000210
# Accuracy on test dataset: 88.66
# Epoch: 51
# Loss: 0.000808
# Epoch: 52
# Loss: 0.000243
# Epoch: 53
# Loss: 0.000674
# Epoch: 54
# Loss: 0.001476
# Epoch: 55
# Loss: 0.001412
# Epoch: 56
# Loss: 0.000242
# Epoch: 57
# Loss: 0.000229
# Epoch: 58
# Loss: 0.000717
# Epoch: 59
# Loss: 0.000092
# Epoch: 60
# Loss: 0.002227
# Accuracy on test dataset: 88.83
# Epoch: 61
# Loss: 0.000337
# Epoch: 62
# Loss: 0.000199
# Epoch: 63
# Loss: 0.000295
# Epoch: 64
# Loss: 0.000886
# Epoch: 65
# Loss: 0.000591
# Epoch: 66
# Loss: 0.000401
# Epoch: 67
# Loss: 0.005339
# Epoch: 68
# Loss: 0.000594
# Epoch: 69
# Loss: 0.000341
# Epoch: 70
# Loss: 0.000277
# Accuracy on test dataset: 89.21
# Epoch: 71
# Loss: 0.001042
# Epoch: 72
# Loss: 0.000152
# Epoch: 73
# Loss: 0.000073
# Epoch: 74
# Loss: 0.000356
# Epoch: 75
# Loss: 0.000759
# Epoch: 76
# Loss: 0.000081
# Epoch: 77
# Loss: 0.000297
# Epoch: 78
# Loss: 0.000425
# Epoch: 79
# Loss: 0.000148
# Epoch: 80
# Loss: 0.000373
# Accuracy on test dataset: 88.16
# Epoch: 81
# Loss: 0.000590
# Epoch: 82
# Loss: 0.000915
# Epoch: 83
# Loss: 0.003257
# Epoch: 84
# Loss: 0.000138
# Epoch: 85
# Loss: 0.000771
# Epoch: 86
# Loss: 0.000799
# Epoch: 87
# Loss: 0.000348
# Epoch: 88
# Loss: 0.000192
# Epoch: 89
# Loss: 0.000327
# Epoch: 90
# Loss: 0.000409
# Accuracy on test dataset: 89.73
# Epoch: 91
# Loss: 0.000019
# Epoch: 92
# Loss: 0.000123
# Epoch: 93
# Loss: 0.000059
# Epoch: 94
# Loss: 0.000117
# Epoch: 95
# Loss: 0.000062
# Epoch: 96
# Loss: 0.000067
# Epoch: 97
# Loss: 0.000056
# Epoch: 98
# Loss: 0.000035
# Epoch: 99
# Loss: 0.000051
# Epoch: 100
# Loss: 0.000063
# Accuracy on test dataset: 89.72
# ------------------------------------------------

# %%
accuracies = np.array(accuracies)
print(f"Test accuracy on dual-domain (Sinkhorn pretrain): avg -> {np.mean(accuracies)*100:.1f}, std -> {np.std(accuracies)*100:.1f}")
# Out:
# Test accuracy on dual-domain (Sinkhorn pretrain): avg -> 89.6, std -> 0.4
